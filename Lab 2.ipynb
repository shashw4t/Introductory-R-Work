# %% [markdown]
# * Read in KKBox's Churn Prediction Challenge (all csv files)
#
# https://www.kaggle.com/c/kkbox-churn-prediction-challenge/data (Links to an external site.)
#
#
#
# 1. How many columns and rows in each file?
#
# 2. Show the right down corner element of each file in R (namely, last row, last column).
#
# 3. Output the odd numbers of columns and even numbers of rows of train.csv
#
# 4. Practice commands: dput, dget, dump, source, save, load, save.image
#
# 5. After class reading: https://bookdown.org/rdpeng/rprogdatascience/using-the-readr-package.html (Links to an external site.)
#
#
# Install the readr Package and use it to read in the data. Any difference in terms of speed in loading the data with readr package’s functions compared with read.table() or read.csv()?

# %%
membersv3 <- read.csv(file = "kkbox-churn-prediction-challenge/members_v3.csv")

# %% [markdown]
# print('columns: ')
# print(ncol(membersv3))
# print('rows: ')
# print(nrow(membersv3))

# %% [markdown]
# The above code doesn't work in Jupyter Notebook and stalls, but works fine in RStudio. After speaking with the professor, she said it was fine to leave a screenshot of the RStudio output instead.
# ![membersv3.png](attachment:membersv3.png)

# %%
membersv3[6769473, 6]
# Out:
# [1] 20151021

# %%
samplev2 <- read.csv(file = "kkbox-churn-prediction-challenge/sample_submission_v2.csv")

# %% [markdown]
# print('columns: ')
# print(ncol(samplev2))
# print('rows: ')
# print(nrow(samplev2))

# %% [markdown]
# ![samplev2.png](attachment:samplev2.png)

# %%
samplev2[907471, 2]
# Out:
# [1] 0

# %%
samplev0 <- read.csv(file = "kkbox-churn-prediction-challenge/sample_submission_zero.csv")

# %% [markdown]
# print('columns: ')
# print(ncol(samplev0))
# print('rows: ')
# print(nrow(samplev0))

# %% [markdown]
# ![samplev0.png](attachment:samplev0.png)

# %%
samplev0[970960, 2]
# Out:
# [1] 0

# %%
train <- read.csv(file = "kkbox-churn-prediction-challenge/train.csv")

# %% [markdown]
# print('columns: ')
# print(ncol(train))
# print('rows: ')
# print(nrow(train))

# %% [markdown]
# ![train.png](attachment:train.png)

# %%
train[992931, 2]
# Out:
# [1] 0

# %%
trainv2 = read.csv(file = "kkbox-churn-prediction-challenge/train_v2.csv")

# %% [markdown]
# print('columns: ')
# print(ncol(trainv2))
# print('rows: ')
# print(nrow(trainv2))

# %% [markdown]
# ![trainv2.png](attachment:trainv2.png)

# %%
trainv2[970960, 2]
# Out:
# [1] 0

# %%
transactions = read.csv(file = "kkbox-churn-prediction-challenge/transactions.csv")

# %% [markdown]
# print('columns: ')
# print(ncol(transactions))
# print('rows: ')
# print(nrow(transactions))

# %% [markdown]
# ![transactions.png](attachment:transactions.png)

# %%
transactions[21547746, 9]
# Out:
# [1] 1

# %%
transactionsv2 = read.csv(file = "kkbox-churn-prediction-challenge/transactions_v2.csv")

# %% [markdown]
# print('columns: ')
# print(ncol(transactionsv2))
# print('rows: ')
# print(nrow(transactionsv2))

# %% [markdown]
# ![transactionsv2.png](attachment:transactionsv2.png)

# %%
transactionsv2[1431009, 9]
# Out:
# [1] 0

# %% [markdown]
# userLogs <- read.csv(file = "kkbox-churn-prediction-challenge/user_logs.csv")

# %% [markdown]
# print('columns: ')
# print(ncol(userLogs))
# print('rows: ')
# print(nrow(userLogs))

# %% [markdown]
# This csv file is 28 GB and does not work in Jupyter or RStudio, so I could not find the rows and columns for this or the item in the bottom right.
# (couldn't read in r studio - Error: cannot allocate vector of size 3.9 Gb)

# %%
userLogsv2 <- read.csv(file = "kkbox-churn-prediction-challenge/user_logs_v2.csv")

# %% [markdown]
# print('columns: ')
# print(ncol(userLogsv2))
# print('rows: ')
# print(nrow(userLogsv2))

# %% [markdown]
# ![userlogsv2.png](attachment:userlogsv2.png)

# %%
userLogsv2[18396362, 9]
# Out:
# [1] 264.288

# %%
#question 4 
install.packages("ISwR")
library(ISwR)
# Out:
# package 'ISwR' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\shash\AppData\Local\Temp\RtmpMBMGUV\downloaded_packages
# Warning message:
# "package 'ISwR' was built under R version 3.6.3"

# %%
dput(energy, file = "energy.R")

# %%
energyGet <- dget("energy.R")
print(energyGet)
# Out:
#    expend stature
# 1    9.21   obese
# 2    7.53    lean
# 3    7.48    lean
# 4    8.08    lean
# 5    8.09    lean
# 6   10.15    lean
# 7    8.40    lean
# 8   10.88    lean
# 9    6.13    lean
# 10   7.90    lean
# 11  11.51   obese
# 12  12.79   obese
# 13   7.05    lean
# 14  11.85   obese
# 15   9.97   obese
# 16   7.48    lean
# 17   8.79   obese
# 18   9.69   obese
# 19   9.68   obese
# 20   7.58    lean
# 21   9.19   obese
# 22   8.11    lean

# %%
a <- c(1, 2, 2232, 444, 555)
b <- list(fruit = c("apple", "pear", "banana"), price = c(1.04, 2.99, 1.56))
dump(c("a", "b"), file = "randomData.R")

# %%
rm(a, b)
source("randomData.R")
str(a)
str(b)
# Out:
#  num [1:5] 1 2 2232 444 555
# List of 2
#  $ fruit: chr [1:3] "apple" "pear" "banana"
#  $ price: num [1:3] 1.04 2.99 1.56

# %%
x <- list(a = matrix(1:4, 2, 2), b = matrix(1:6, 3, 2))
y <- list(a=1:5, b = rnorm(10))
save(x, y, file = "saveTest.rda")

# %%
rm(x, y)
load("saveTest.rda")
x
y
# Out:
# $a
#      [,1] [,2]
# [1,]    1    3
# [2,]    2    4
#
# $b
#      [,1] [,2]
# [1,]    1    4
# [2,]    2    5
# [3,]    3    6
# $a
# [1] 1 2 3 4 5
#
# $b
#  [1]  0.83869082 -0.64475417  0.25753818 -1.13263212 -1.28813686 -0.68292624
#  [7] -2.17810350 -0.06877663  0.91555278  0.35775784

# %%
save.image(file = "saveImageTest.RData")

# %%
rm(x, y)
load("saveImageTest.RData")
x
y
# Out:
# $a
#      [,1] [,2]
# [1,]    1    3
# [2,]    2    4
#
# $b
#      [,1] [,2]
# [1,]    1    4
# [2,]    2    5
# [3,]    3    6
# $a
# [1] 1 2 3 4 5
#
# $b
#  [1]  0.83869082 -0.64475417  0.25753818 -1.13263212 -1.28813686 -0.68292624
#  [7] -2.17810350 -0.06877663  0.91555278  0.35775784

# %%
#question 5
install.packages("readr") 
library(readr)
# Out:
# also installing the dependencies 'rlang', 'cli', 'hms', 'lifecycle', 'vroom'
#   There are binary versions available but the source versions are later:
#           binary source needs_compilation
# rlang     0.4.11  1.0.6              TRUE
# cli        2.5.0  3.4.1              TRUE
# hms        1.0.0  1.1.2             FALSE
# lifecycle  1.0.0  1.0.2             FALSE
# vroom      1.4.0  1.6.0              TRUE
# readr      1.4.0  2.1.3              TRUE
#
#   Binaries will be installed
# package 'rlang' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'rlang'"Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problem copying C:\Users\shash\anaconda3\envs\r-tutorial\Lib\R\library\00LOCK\rlang\libs\x64\rlang.dll to C:\Users\shash\anaconda3\envs\r-tutorial\Lib\R\library\rlang\libs\x64\rlang.dll: Permission denied"Warning message:
# "restored 'rlang'"
# package 'cli' successfully unpacked and MD5 sums checked
# ...

# %%
transactionsReadr <- read_csv(file = "kkbox-churn-prediction-challenge/transactions.csv")
# Out:
# Error in read_csv(file = "kkbox-churn-prediction-challenge/transactions.csv"): could not find function "read_csv"
# Traceback:

# %% [markdown]
# This package was not able to be downloaded in Jupyter, but worked in RStudio. It was noticeably faster than read.csv, maybe 3 times faster at loading in the csv.
# ![readR.png](attachment:readR.png)
